# %% [markdown]
# <a href="https://colab.research.google.com/github/lovegohome/ML/blob/main/ch05_regression(01_05).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 파이썬 머신러닝 완벽가이드
# # ch05. 회귀(regression)

# %% [markdown]
# 회귀분석의 쟁점
#
# 1. x와 y가 어떤 관계인지
# 2. x가 y에게 어떤 영향을 미치는지
#    어떤 회귀 계수가 최적의 회귀계수일까(경사 하강법, Gradient Descent)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1) 어디가 bset일까? D
#
# 2) 그걸 어떻게 찾을까?
#   - 미분=0 되는 지점 중 Global Minmum
#   - 노력↓ 결과↑ = 가성비 좋게 찾는 방법이 필요
#   - 주의) C에서 왼쪽으로 이동하며 찾을 경우 A를 best로 여김(local minimum)
#   - 미니배치(배치학습법): 그래프의 여러 지점에서 시작해서 미분=0 지점 찾음. 그 중 비교.
#
#   (ex. 앙상블학습법의 베깅, 보팅 중 보팅)

# %% [markdown]
# **cross-validation**
# - 앙상블학습법(중복o)과 다르지만 아이디어적으로는 같은 맥락
# - train data가 달라진 꼴. (중복x)
# - 코끼리를 여러 방향으로 봐야 제대로 볼 수 있듯이 회귀도 여러 방향으로 봐야 error를 줄인다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - A: under fitting(약 20, 30)
# - B: 가장 경제적이고 효율적인 모델
# - C: over fitting(약 99, 98)

# %% [markdown]
# 참고
# - p.304 회귀평가지표
# - p.318 편향-분산 트레이오프(분산이 더 큰 문제, 그래서 정규화 과정이 중요)

# %% [markdown]
# cf. 어떤 모델을 써야할지 고민될 때 = 어떤 아웃풋을 원하는지를 보자.
#   - 자기가 원하는 결과가 뭔지, 뭐가 궁금한지 모르면 할 수 없음
#   - ex 어떤 관계인지 궁금해 = correlation
#   - ex 수리식 값으로 비교 원해 = 회귀식
#   - ex ratio, class = 분류
#   - 그 외에는 데이터 얻는 게 관건.
#     - 데이터 feature가 설명을 못하면:
#       다른 new feature 찾거나, parameter이용해서 tuning
